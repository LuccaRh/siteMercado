# %%
import pandas as pd
import requests
from dotenv import load_dotenv
import os
import concurrent.futures
from translate import Translator

# %%
ingredientes1k = pd.read_csv(r"top-1k-ingredients.csv", delimiter = ";")
ingredientes1k.head()
# Out:
#                 nome       id
# 0  five spice powder  1002002
# 1       acorn squash    11482
# 2        adobo sauce     6979
# 3       agave nectar    19912
# 4           ahi tuna    15117

# %%
load_dotenv()
apikey = os.getenv('spoonacularApikey')
#colocar no git ignore o .env

def obter_informacoes_produto(id_produto):
    url = f'https://api.spoonacular.com/food/ingredients/{id_produto}/information?amount=1&apiKey={apikey}'
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    else:
        return None
    
def obter_informacoes_para_linha(row):
    return obter_informacoes_produto(row[1])

# %%
with concurrent.futures.ThreadPoolExecutor() as executor:
    resultados = list(executor.map(obter_informacoes_para_linha, ingredientes1k.head(30).itertuples(index=False)))

# Criar um novo DataFrame com as informações dos produtos
dfSemUnit = pd.DataFrame(resultados)
dfSemUnit.head()
# Out:
#         id           original       originalName               name  amount  \
# 0  1002002  five spice powder  five spice powder  five spice powder     1.0
# 1    11482       acorn squash       acorn squash       acorn squash     1.0
# 2     6979        adobo sauce        adobo sauce        adobo sauce     1.0
# 3    19912        agave syrup        agave syrup        agave syrup     1.0
# 4    15117    ahi tuna steaks    ahi tuna steaks    ahi tuna steaks     1.0
#
#   unit unitShort unitLong                                      possibleUnits  \
# 0                                              [g, oz, teaspoon, tablespoon]
# 1                                                [squash, piece, g, oz, cup]
# 2                                         [g, oz, teaspoon, cup, tablespoon]
# 3                                [g, oz, teaspoon, cup, serving, tablespoon]
# 4                          [strip, steak, piece, g, ounce, fillet, inch, ...
#
#                            estimatedCost consistency  \
# 0    {'value': 4.64, 'unit': 'US Cents'}       solid
# 1   {'value': 94.82, 'unit': 'US Cents'}       solid
# 2    {'value': 0.96, 'unit': 'US Cents'}       solid
# 3    {'value': 0.71, 'unit': 'US Cents'}      liquid
# 4  {'value': 581.91, 'unit': 'US Cents'}       solid
#
#                                 aisle                          image meta  \
# 0  Ethnic Foods;Spices and Seasonings  chinese-five-spice-powder.png   []
# 1                             Produce               acorn-squash.jpg   []
# 2                        Ethnic Foods                    harissa.jpg   []
# 3           Ethnic Foods;Health Foods                      agave.png   []
# 4                             Seafood                 tuna-steak.png   []
#
#                                            nutrition  \
# 0  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 1  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 2  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 3  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 4  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
#
#                                       categoryPath shoppingListUnits
# 0                       [seasoning mix, seasoning]               NaN
# 1               [winter squash, squash, vegetable]          [pieces]
# 2                                               []               NaN
# 3                                          [syrup]          [ounces]
# 4  [tuna steak, fresh tuna, tuna, fish, main dish]  [ounces, pounds]

# %%
colunasOrdenadas = ['possibleUnits'] + [coluna for coluna in dfSemUnit.columns if coluna != 'possibleUnits']
dfSemUnit = dfSemUnit[colunasOrdenadas]
dfSemUnit.head()
# Out:
#                                        possibleUnits       id  \
# 0                      [g, oz, teaspoon, tablespoon]  1002002
# 1                        [squash, piece, g, oz, cup]    11482
# 2                 [g, oz, teaspoon, cup, tablespoon]     6979
# 3        [g, oz, teaspoon, cup, serving, tablespoon]    19912
# 4  [strip, steak, piece, g, ounce, fillet, inch, ...    15117
#
#             original       originalName               name  amount unit  \
# 0  five spice powder  five spice powder  five spice powder     1.0
# 1       acorn squash       acorn squash       acorn squash     1.0
# 2        adobo sauce        adobo sauce        adobo sauce     1.0
# 3        agave syrup        agave syrup        agave syrup     1.0
# 4    ahi tuna steaks    ahi tuna steaks    ahi tuna steaks     1.0
#
#   unitShort unitLong                          estimatedCost consistency  \
# 0                       {'value': 4.64, 'unit': 'US Cents'}       solid
# 1                      {'value': 94.82, 'unit': 'US Cents'}       solid
# 2                       {'value': 0.96, 'unit': 'US Cents'}       solid
# 3                       {'value': 0.71, 'unit': 'US Cents'}      liquid
# 4                     {'value': 581.91, 'unit': 'US Cents'}       solid
#
#                                 aisle                          image meta  \
# 0  Ethnic Foods;Spices and Seasonings  chinese-five-spice-powder.png   []
# 1                             Produce               acorn-squash.jpg   []
# 2                        Ethnic Foods                    harissa.jpg   []
# 3           Ethnic Foods;Health Foods                      agave.png   []
# 4                             Seafood                 tuna-steak.png   []
#
#                                            nutrition  \
# 0  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 1  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 2  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 3  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 4  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
#
#                                       categoryPath shoppingListUnits
# 0                       [seasoning mix, seasoning]               NaN
# 1               [winter squash, squash, vegetable]          [pieces]
# 2                                               []               NaN
# 3                                          [syrup]          [ounces]
# 4  [tuna steak, fresh tuna, tuna, fish, main dish]  [ounces, pounds]

# %%
def obter_informacoes_produto_com_Unit(id_produto,unit):
    url = f'https://api.spoonacular.com/food/ingredients/{id_produto}/information?amount=1&apiKey={apikey}&unit={unit}'
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    else:
        return None
    
def obter_informacoes_para_linha_com_Unit(row):
    return obter_informacoes_produto_com_Unit(row[1], row[0][0])

# %%
with concurrent.futures.ThreadPoolExecutor() as executor:
    resultados = list(executor.map(obter_informacoes_para_linha_com_Unit, dfSemUnit.head(30).itertuples(index=False)))

# Criar um novo DataFrame com as informações dos produtos
dfComUnit = pd.DataFrame(resultados)
dfComUnit.head()
# Out:
#           id              original          originalName  \
# 0    1002002     five spice powder     five spice powder
# 1      11482          acorn squash          acorn squash
# 2       6979           adobo sauce           adobo sauce
# 3      19912           agave syrup           agave syrup
# 4      15117       ahi tuna steaks       ahi tuna steaks
# 5      93606   alfredo pasta sauce   alfredo pasta sauce
# 6    1002050   pure almond extract   pure almond extract
# 7      93740        ground almonds        ground almonds
# 8      93607          almond drink          almond drink
# 9      12061                almond                almond
# 10  10014534              amaretto              amaretto
# 11  10211962           ancho chili           ancho chili
# 12     15001            boquerones            boquerones
# 13      7064    andouille sausages    andouille sausages
# 14     18087    angelfood cake mix    angelfood cake mix
# 15  10020420       angelhair pasta       angelhair pasta
# 16     93653      Cocktail Bitters      Cocktail Bitters
# 17      9003                apples                apples
# 18     19294   apple butter spread   apple butter spread
# 19   1009016           apple cider           apple cider
# 20      9016           apple juice           apple juice
# 21   1042035       apple pie spice       apple pie spice
# 22     19719           apricot jam           apricot jam
# 23      9021              apricots              apricots
# 24  10020052      rice for risotto      rice for risotto
# 25     20003      arrowroot powder      arrowroot powder
# 26     93828  marinated artichokes  marinated artichokes
# 27     11007            artichokes            artichokes
# 28     11959                rocket                rocket
# 29   1032035     asafoetida powder     asafoetida powder
#
#                     name  amount     unit unitShort unitLong  \
# 0      five spice powder     1.0        g         g     gram
# 1           acorn squash     1.0   squash    squash   squash
# 2            adobo sauce     1.0        g         g     gram
# 3            agave syrup     1.0        g         g     gram
# 4        ahi tuna steaks     1.0    strip     strip    strip
# 5    alfredo pasta sauce     1.0        g         g     gram
# 6    pure almond extract     1.0     drop      drop     drop
# 7         ground almonds     1.0        g         g     gram
# 8           almond drink     1.0        g         g     gram
# 9                 almond     1.0  handful   handful  handful
# 10              amaretto     1.0        g         g     gram
# 11           ancho chili     1.0    piece
# 12            boquerones     1.0      can       can      can
# 13    andouille sausages     1.0  package       pkg  package
# 14    angelfood cake mix     1.0  package       pkg  package
# 15       angelhair pasta     1.0  package       pkg  package
# 16      Cocktail Bitters     1.0        g         g     gram
# 17                apples     1.0    small     small    small
# 18   apple butter spread     1.0        g         g     gram
# 19           apple cider     1.0        g         g     gram
# 20           apple juice     1.0        g         g     gram
# 21       apple pie spice     1.0        g         g     gram
# 22           apricot jam     1.0        g         g     gram
# 23              apricots     1.0  apricot   apricot  apricot
# 24      rice for risotto     1.0        g         g     gram
# 25      arrowroot powder     1.0        g         g     gram
# 26  marinated artichokes     1.0      can       can      can
# 27            artichokes     1.0      can       can      can
# 28                rocket     1.0  handful   handful  handful
# 29     asafoetida powder     1.0        g         g     gram
#
#                                         possibleUnits  \
# 0                       [g, oz, teaspoon, tablespoon]
# 1                         [squash, piece, g, oz, cup]
# 2                  [g, oz, teaspoon, cup, tablespoon]
# 3         [g, oz, teaspoon, cup, serving, tablespoon]
# 4   [strip, steak, piece, g, ounce, fillet, inch, ...
# 5                                   [g, jar, oz, cup]
# 6   [drop, g, oz, dash, teaspoon, cup, serving, ta...
# 7                            [g, oz, cup, tablespoon]
# 8                            [g, oz, cup, tablespoon]
# 9   [handful, piece, g, almond, ounce, oz, teaspoo...
# 10  [g, oz, teaspoon, fluid ounce, cup, serving, s...
# 11                                     [piece, g, oz]
# 12  [can, piece, filet, g, tin, ounce, fillet, oz,...
# 13                   [package, piece, g, oz, serving]
# 14       [package, piece, g, ounce, box, oz, serving]
# 15     [package, g, bag, box, nest, oz, cup, serving]
# 16         [g, oz, dash, dashe, teaspoon, tablespoon]
# 17  [small, large, piece, slice, g, extra small, m...
# 18                  [g, oz, cup, serving, tablespoon]
# 19  [g, drink box, oz, teaspoon, bottle NFS, fluid...
# 20  [g, drink box, oz, teaspoon, bottle NFS, fluid...
# 21                 [g, oz, teaspoon, cup, tablespoon]
# 22     [g, oz, packet, teaspoon, serving, tablespoon]
# 23                       [apricot, piece, g, oz, cup]
# 24                              [g, oz, cup, serving]
# 25                 [g, oz, teaspoon, cup, tablespoon]
# 26             [can, piece, g, jar, oz, cup, serving]
# 27      [can, piece, g, tin, artichoke, box, jar, oz]
# 28  [handful, piece, leave, g, bag, sprig, bunch, ...
# 29                 [g, oz, teaspoon, cup, tablespoon]
#
#                             estimatedCost consistency  \
# 0     {'value': 4.64, 'unit': 'US Cents'}       solid
# 1    {'value': 94.82, 'unit': 'US Cents'}       solid
# 2     {'value': 0.96, 'unit': 'US Cents'}       solid
# 3     {'value': 0.71, 'unit': 'US Cents'}      liquid
# 4   {'value': 136.92, 'unit': 'US Cents'}       solid
# 5     {'value': 0.86, 'unit': 'US Cents'}       solid
# 6     {'value': 1.79, 'unit': 'US Cents'}      liquid
# 7      {'value': 2.0, 'unit': 'US Cents'}       solid
# 8      {'value': 0.2, 'unit': 'US Cents'}      liquid
# 9    {'value': 53.57, 'unit': 'US Cents'}       solid
# 10    {'value': 2.09, 'unit': 'US Cents'}       solid
# 11   {'value': 10.73, 'unit': 'US Cents'}       solid
# 12  {'value': 196.43, 'unit': 'US Cents'}       solid
# 13  {'value': 471.43, 'unit': 'US Cents'}       solid
# 14  {'value': 194.14, 'unit': 'US Cents'}       solid
# 15   {'value': 96.43, 'unit': 'US Cents'}       solid
# 16    {'value': 6.68, 'unit': 'US Cents'}       solid
# 17   {'value': 49.34, 'unit': 'US Cents'}       solid
# 18    {'value': 0.43, 'unit': 'US Cents'}       solid
# 19    {'value': 0.14, 'unit': 'US Cents'}       solid
# 20    {'value': 0.14, 'unit': 'US Cents'}      liquid
# 21   {'value': 21.65, 'unit': 'US Cents'}       solid
# 22    {'value': 1.25, 'unit': 'US Cents'}       solid
# 23   {'value': 15.48, 'unit': 'US Cents'}       solid
# 24    {'value': 0.75, 'unit': 'US Cents'}       solid
# 25    {'value': 1.07, 'unit': 'US Cents'}       solid
# 26  {'value': 424.29, 'unit': 'US Cents'}       solid
# 27   {'value': 187.5, 'unit': 'US Cents'}       solid
# 28   {'value': 28.57, 'unit': 'US Cents'}       solid
# 29   {'value': 12.36, 'unit': 'US Cents'}       solid
#
#                                          aisle  \
# 0           Ethnic Foods;Spices and Seasonings
# 1                                      Produce
# 2                                 Ethnic Foods
# 3                    Ethnic Foods;Health Foods
# 4                                      Seafood
# 5                               Pasta and Rice
# 6                                       Baking
# 7                     Gluten Free;Health Foods
# 8                      Milk, Eggs, Other Dairy
# 9                                         Nuts
# 10                         Alcoholic Beverages
# 11  Produce;Ethnic Foods;Spices and Seasonings
# 12                   Canned and Jarred;Seafood
# 13                                        Meat
# 14                                      Baking
# 15                              Pasta and Rice
# 16                         Alcoholic Beverages
# 17                                     Produce
# 18                Nut butters, Jams, and Honey
# 19                                   Beverages
# 20                                   Beverages
# 21                       Spices and Seasonings
# 22                Nut butters, Jams, and Honey
# 23                                     Produce
# 24                              Pasta and Rice
# 25             Gluten Free;Health Foods;Baking
# 26                           Canned and Jarred
# 27                                     Produce
# 28                                     Produce
# 29                       Spices and Seasonings
#
#                               image meta  \
# 0     chinese-five-spice-powder.png   []
# 1                  acorn-squash.jpg   []
# 2                       harissa.jpg   []
# 3                         agave.png   []
# 4                    tuna-steak.png   []
# 5                 alfredo-sauce.png   []
# 6                       extract.png   []
# 7   almond-meal-or-almond-flour.jpg   []
# 8                   almond-milk.png   []
# 9                       almonds.jpg   []
# 10     temporary-orange-liqueur.jpg   []
# 11           dried-arbol-chiles.jpg   []
# 12                    anchovies.jpg   []
# 13               smoked-sausage.jpg   []
# 14              angel-food-cake.jpg   []
# 15                    angelhair.jpg   []
# 16                   dark-sauce.jpg   []
# 17                        apple.jpg   []
# 18                  apple-jelly.jpg   []
# 19                  apple-cider.jpg   []
# 20                  apple-juice.jpg   []
# 21                 garam-masala.jpg   []
# 22                  apricot-jam.jpg   []
# 23                      apricot.jpg   []
# 24                 arborio-rice.png   []
# 25                 white-powder.jpg   []
# 26             artichoke-hearts.png   []
# 27                   artichokes.png   []
# 28      arugula-or-rocket-salad.jpg   []
# 29                 curry-powder.jpg   []
#
#                                             nutrition  \
# 0   {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 1   {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 2   {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 3   {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 4   {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 5   {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 6   {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 7   {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 8   {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 9   {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 10  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 11  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 12  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 13  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 14  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 15  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 16  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 17  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 18  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 19  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 20  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 21  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 22  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 23  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 24  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 25  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 26  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 27  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 28  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 29  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
#
#                                          categoryPath  \
# 0                          [seasoning mix, seasoning]
# 1                  [winter squash, squash, vegetable]
# 2                                                  []
# 3                                             [syrup]
# 4     [tuna steak, fresh tuna, tuna, fish, main dish]
# 5                                [cream sauce, sauce]
# 6                                           [extract]
# 7                                                  []
# 8                         [nut milk, milk substitute]
# 9                                   [tree nuts, nuts]
# 10                  [liqueur, alcoholic drink, drink]
# 11  [dried red chili pepper, dried chili pepper, c...
# 12                       [anchovies, fish, main dish]
# 13    [smoked sausage, sausage, processed meat, meat]
# 14                    [cake mix, baking mix category]
# 15                                            [pasta]
# 16                                                 []
# 17                                            [fruit]
# 18               [fruit butter, fruit spread, spread]
# 19                                            [drink]
# 20                        [fruit juice, juice, drink]
# 21                         [seasoning mix, seasoning]
# 22                        [jam, fruit spread, spread]
# 23                                            [fruit]
# 24                                     [rice, grains]
# 25                                           [starch]
# 26                             [artichoke, vegetable]
# 27                                        [vegetable]
# 28                                [greens, vegetable]
# 29                                           [spices]
#
#                    shoppingListUnits
# 0                                NaN
# 1                           [pieces]
# 2                                NaN
# 3                           [ounces]
# 4                   [ounces, pounds]
# 5                                NaN
# 6                           [ounces]
# 7                   [ounces, pounds]
# 8          [ounces, quarts, gallons]
# 9                   [ounces, pounds]
# 10                               NaN
# 11                          [pieces]
# 12                  [ounces, pounds]
# 13                  [ounces, pounds]
# 14                  [ounces, pounds]
# 15                  [ounces, pounds]
# 16                               NaN
# 17                          [pieces]
# 18                               NaN
# 19                               NaN
# 20  [ounces, pints, quarts, gallons]
# 21                               NaN
# 22                               NaN
# 23                          [pieces]
# 24                  [ounces, pounds]
# 25                          [ounces]
# 26                          [pieces]
# 27                          [pieces]
# 28                          [pieces]
# 29                               NaN

# %%
dfComUnit.rename(columns={'unit': 'Unidade'}, inplace=True)

# %%
dfComUnit['Valor'] = dfComUnit['estimatedCost'].apply(lambda x: x['value'])
dfComUnit.head()
# Out:
#         id           original       originalName               name  amount  \
# 0  1002002  five spice powder  five spice powder  five spice powder     1.0
# 1    11482       acorn squash       acorn squash       acorn squash     1.0
# 2     6979        adobo sauce        adobo sauce        adobo sauce     1.0
# 3    19912        agave syrup        agave syrup        agave syrup     1.0
# 4    15117    ahi tuna steaks    ahi tuna steaks    ahi tuna steaks     1.0
#
#   Unidade unitShort unitLong  \
# 0       g         g     gram
# 1  squash    squash   squash
# 2       g         g     gram
# 3       g         g     gram
# 4   strip     strip    strip
#
#                                        possibleUnits  \
# 0                      [g, oz, teaspoon, tablespoon]
# 1                        [squash, piece, g, oz, cup]
# 2                 [g, oz, teaspoon, cup, tablespoon]
# 3        [g, oz, teaspoon, cup, serving, tablespoon]
# 4  [strip, steak, piece, g, ounce, fillet, inch, ...
#
#                            estimatedCost consistency  \
# 0    {'value': 4.64, 'unit': 'US Cents'}       solid
# 1   {'value': 94.82, 'unit': 'US Cents'}       solid
# 2    {'value': 0.96, 'unit': 'US Cents'}       solid
# 3    {'value': 0.71, 'unit': 'US Cents'}      liquid
# 4  {'value': 136.92, 'unit': 'US Cents'}       solid
#
#                                 aisle                          image meta  \
# 0  Ethnic Foods;Spices and Seasonings  chinese-five-spice-powder.png   []
# 1                             Produce               acorn-squash.jpg   []
# 2                        Ethnic Foods                    harissa.jpg   []
# 3           Ethnic Foods;Health Foods                      agave.png   []
# 4                             Seafood                 tuna-steak.png   []
#
#                                            nutrition  \
# 0  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 1  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 2  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 3  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 4  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
#
#                                       categoryPath shoppingListUnits   Valor  \
# 0                       [seasoning mix, seasoning]               NaN    4.64
# 1               [winter squash, squash, vegetable]          [pieces]   94.82
# 2                                               []               NaN    0.96
# 3                                          [syrup]          [ounces]    0.71
# 4  [tuna steak, fresh tuna, tuna, fish, main dish]  [ounces, pounds]  136.92
#
#                       Nome
# 0  cinco especiarias em pó
# 1           Abóbora-bolota
# 2              molho adobo
# 3          xarope de agave
# 4        bifes de atum ahi

# %%
def traduzir_texto(texto, idioma_destino='pt-BR'):
    translator = Translator(to_lang=idioma_destino)
    traducao = translator.translate(texto)
    return traducao

# %%
dfComUnit['Nome'] = dfComUnit['name'].apply(lambda x: traduzir_texto(x))
dfComUnit.head()
# Out:
#         id           original       originalName               name  amount  \
# 0  1002002  five spice powder  five spice powder  five spice powder     1.0
# 1    11482       acorn squash       acorn squash       acorn squash     1.0
# 2     6979        adobo sauce        adobo sauce        adobo sauce     1.0
# 3    19912        agave syrup        agave syrup        agave syrup     1.0
# 4    15117    ahi tuna steaks    ahi tuna steaks    ahi tuna steaks     1.0
#
#   Unidade unitShort unitLong  \
# 0       g         g     gram
# 1  squash    squash   squash
# 2       g         g     gram
# 3       g         g     gram
# 4   strip     strip    strip
#
#                                        possibleUnits  \
# 0                      [g, oz, teaspoon, tablespoon]
# 1                        [squash, piece, g, oz, cup]
# 2                 [g, oz, teaspoon, cup, tablespoon]
# 3        [g, oz, teaspoon, cup, serving, tablespoon]
# 4  [strip, steak, piece, g, ounce, fillet, inch, ...
#
#                            estimatedCost consistency  \
# 0    {'value': 4.64, 'unit': 'US Cents'}       solid
# 1   {'value': 94.82, 'unit': 'US Cents'}       solid
# 2    {'value': 0.96, 'unit': 'US Cents'}       solid
# 3    {'value': 0.71, 'unit': 'US Cents'}      liquid
# 4  {'value': 136.92, 'unit': 'US Cents'}       solid
#
#                                 aisle                          image meta  \
# 0  Ethnic Foods;Spices and Seasonings  chinese-five-spice-powder.png   []
# 1                             Produce               acorn-squash.jpg   []
# 2                        Ethnic Foods                    harissa.jpg   []
# 3           Ethnic Foods;Health Foods                      agave.png   []
# 4                             Seafood                 tuna-steak.png   []
#
#                                            nutrition  \
# 0  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 1  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 2  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 3  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
# 4  {'nutrients': [{'name': 'Vitamin B6', 'amount'...
#
#                                       categoryPath shoppingListUnits   Valor  \
# 0                       [seasoning mix, seasoning]               NaN    4.64
# 1               [winter squash, squash, vegetable]          [pieces]   94.82
# 2                                               []               NaN    0.96
# 3                                          [syrup]          [ounces]    0.71
# 4  [tuna steak, fresh tuna, tuna, fish, main dish]  [ounces, pounds]  136.92
#
#                       Nome
# 0  cinco especiarias em pó
# 1           Abóbora-bolota
# 2              molho adobo
# 3          xarope de agave
# 4        bifes de atum ahi

# %%
colunasDB = ['id','Nome','Valor','Unidade','image']
dfDB = dfComUnit[colunasDB]
dfDB.head()
# Out:
#         id                     Nome   Valor Unidade  \
# 0  1002002  cinco especiarias em pó    4.64       g
# 1    11482           Abóbora-bolota   94.82  squash
# 2     6979              molho adobo    0.96       g
# 3    19912          xarope de agave    0.71       g
# 4    15117        bifes de atum ahi  136.92   strip
#
#                            image
# 0  chinese-five-spice-powder.png
# 1               acorn-squash.jpg
# 2                    harissa.jpg
# 3                      agave.png
# 4                 tuna-steak.png

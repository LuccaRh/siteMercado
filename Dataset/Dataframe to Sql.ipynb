# %%
import pandas as pd
import numpy as np
import pyodbc

# %%
df = pd.read_csv(r"SpoonacularApiDatasetSimples.csv", delimiter = ",")
df
# Out:
#           id                       Nome  Valor R$  Unidade  \
# 0    1002002    cinco especiarias em pó      0.23     gram
# 1      11482             Abóbora-bolota      4.67   squash
# 2       6979                molho adobo      0.05     gram
# 3      19912            xarope de agave      0.04     gram
# 4      15117          bifes de atum ahi      6.75    strip
# 5      93606     molho macarrão alfredo      0.04     gram
# 6    1002050         Extrato de amêndoa      0.09     drop
# 7      93740            Amêndoas Moídas      0.10     gram
# 8      93607          bebida de amêndoa      0.01     gram
# 9      12061                    amêndoa      2.64  handful
# 10  10014534                   Amaretto      0.10     gram
# 11  10211962                ancho chili      0.53    piece
# 12     15001                 boquerones      9.68      can
# 13      7064        salsichas andouille     23.24  package
# 14     18087   mix de bolo de angelfood      9.57  package
# 15  10020420         macarrão angelhair      4.75  package
# 16     93653           Cocktail Bitters      0.33     gram
# 17      9003                      maçãs      2.43    small
# 18     19294  pasta de manteiga de maçã      0.02     gram
# 19   1009016              sidra de maçã      0.01     gram
# 20      9016               suco de maçã      0.01     gram
# 21   1042035   tempero de torta de maçã      1.07     gram
# 22     19719          geleia de damasco      0.06     gram
# 23      9021                   Damascos      0.76  apricot
# 24  10020052          arroz para risoto      0.04     gram
# 25     20003              pó de araruta      0.05     gram
# 26     93828      alcachofras marinadas     20.92      can
# 27     11007                Alcachofras      9.24      can
# 28     11959                    foguete      1.41  handful
# 29   1032035              pó asafoetida      0.61     gram
#
#                               image
# 0     chinese-five-spice-powder.png
# 1                  acorn-squash.jpg
# 2                       harissa.jpg
# 3                         agave.png
# 4                    tuna-steak.png
# 5                 alfredo-sauce.png
# 6                       extract.png
# 7   almond-meal-or-almond-flour.jpg
# 8                   almond-milk.png
# 9                       almonds.jpg
# 10     temporary-orange-liqueur.jpg
# 11           dried-arbol-chiles.jpg
# 12                    anchovies.jpg
# 13               smoked-sausage.jpg
# 14              angel-food-cake.jpg
# 15                    angelhair.jpg
# 16                   dark-sauce.jpg
# 17                        apple.jpg
# 18                  apple-jelly.jpg
# 19                  apple-cider.jpg
# 20                  apple-juice.jpg
# 21                 garam-masala.jpg
# 22                  apricot-jam.jpg
# 23                      apricot.jpg
# 24                 arborio-rice.png
# 25                 white-powder.jpg
# 26             artichoke-hearts.png
# 27                   artichokes.png
# 28      arugula-or-rocket-salad.jpg
# 29                 curry-powder.jpg

# %%
#Gerar números aleatórios para representar quantidade de produtos
df['Quantidade'] = np.random.randint(10, 31, size=len(df))
#multiplicar por 100 unidades pequenas
df.loc[df['Unidade'].isin(['gram', 'drop','piece','apricot']), 'Quantidade'] *= 10
df
# Out:
#           id                       Nome  Valor R$  Unidade  \
# 0    1002002    cinco especiarias em pó      0.23     gram
# 1      11482             Abóbora-bolota      4.67   squash
# 2       6979                molho adobo      0.05     gram
# 3      19912            xarope de agave      0.04     gram
# 4      15117          bifes de atum ahi      6.75    strip
# 5      93606     molho macarrão alfredo      0.04     gram
# 6    1002050         Extrato de amêndoa      0.09     drop
# 7      93740            Amêndoas Moídas      0.10     gram
# 8      93607          bebida de amêndoa      0.01     gram
# 9      12061                    amêndoa      2.64  handful
# 10  10014534                   Amaretto      0.10     gram
# 11  10211962                ancho chili      0.53    piece
# 12     15001                 boquerones      9.68      can
# 13      7064        salsichas andouille     23.24  package
# 14     18087   mix de bolo de angelfood      9.57  package
# 15  10020420         macarrão angelhair      4.75  package
# 16     93653           Cocktail Bitters      0.33     gram
# 17      9003                      maçãs      2.43    small
# 18     19294  pasta de manteiga de maçã      0.02     gram
# 19   1009016              sidra de maçã      0.01     gram
# 20      9016               suco de maçã      0.01     gram
# 21   1042035   tempero de torta de maçã      1.07     gram
# 22     19719          geleia de damasco      0.06     gram
# 23      9021                   Damascos      0.76  apricot
# 24  10020052          arroz para risoto      0.04     gram
# 25     20003              pó de araruta      0.05     gram
# 26     93828      alcachofras marinadas     20.92      can
# 27     11007                Alcachofras      9.24      can
# 28     11959                    foguete      1.41  handful
# 29   1032035              pó asafoetida      0.61     gram
#
#                               image  Quantidade
# 0     chinese-five-spice-powder.png         210
# 1                  acorn-squash.jpg          13
# 2                       harissa.jpg         160
# 3                         agave.png         270
# 4                    tuna-steak.png          27
# 5                 alfredo-sauce.png         120
# 6                       extract.png         270
# 7   almond-meal-or-almond-flour.jpg         150
# 8                   almond-milk.png         170
# 9                       almonds.jpg          25
# 10     temporary-orange-liqueur.jpg         270
# 11           dried-arbol-chiles.jpg         130
# 12                    anchovies.jpg          19
# 13               smoked-sausage.jpg          20
# 14              angel-food-cake.jpg          16
# 15                    angelhair.jpg          10
# 16                   dark-sauce.jpg         140
# 17                        apple.jpg          28
# 18                  apple-jelly.jpg         250
# 19                  apple-cider.jpg         140
# 20                  apple-juice.jpg         230
# 21                 garam-masala.jpg         240
# 22                  apricot-jam.jpg         230
# 23                      apricot.jpg         300
# 24                 arborio-rice.png         190
# 25                 white-powder.jpg         270
# 26             artichoke-hearts.png          16
# 27                   artichokes.png          13
# 28      arugula-or-rocket-salad.jpg          22
# 29                 curry-powder.jpg         260

# %%
#tentei fazer utilizando bibliotecas, mas não é muito preciso
def traducao(unidade):
    if unidade == 'gram':
        return 'gramas'
    elif unidade in ['squash', 'apricot', 'small']:
        return 'unidade'
    elif unidade == 'strip':
        return 'tira'
    elif unidade == 'drop':
        return 'gota'
    elif unidade == 'handful':
        return 'punhado'
    elif unidade == 'piece':
        return 'pedaço'
    elif unidade == 'package':
        return 'pacote'
    elif unidade == 'can':
        return 'lata'
    
df['Unidade'] = df['Unidade'].apply(lambda x: traducao(x))
df
# Out:
#           id                       Nome  Valor R$  Unidade  \
# 0    1002002    cinco especiarias em pó      0.23   gramas
# 1      11482             Abóbora-bolota      4.67  unidade
# 2       6979                molho adobo      0.05   gramas
# 3      19912            xarope de agave      0.04   gramas
# 4      15117          bifes de atum ahi      6.75     tira
# 5      93606     molho macarrão alfredo      0.04   gramas
# 6    1002050         Extrato de amêndoa      0.09     gota
# 7      93740            Amêndoas Moídas      0.10   gramas
# 8      93607          bebida de amêndoa      0.01   gramas
# 9      12061                    amêndoa      2.64  punhado
# 10  10014534                   Amaretto      0.10   gramas
# 11  10211962                ancho chili      0.53   pedaço
# 12     15001                 boquerones      9.68     lata
# 13      7064        salsichas andouille     23.24   pacote
# 14     18087   mix de bolo de angelfood      9.57   pacote
# 15  10020420         macarrão angelhair      4.75   pacote
# 16     93653           Cocktail Bitters      0.33   gramas
# 17      9003                      maçãs      2.43  unidade
# 18     19294  pasta de manteiga de maçã      0.02   gramas
# 19   1009016              sidra de maçã      0.01   gramas
# 20      9016               suco de maçã      0.01   gramas
# 21   1042035   tempero de torta de maçã      1.07   gramas
# 22     19719          geleia de damasco      0.06   gramas
# 23      9021                   Damascos      0.76  unidade
# 24  10020052          arroz para risoto      0.04   gramas
# 25     20003              pó de araruta      0.05   gramas
# 26     93828      alcachofras marinadas     20.92     lata
# 27     11007                Alcachofras      9.24     lata
# 28     11959                    foguete      1.41  punhado
# 29   1032035              pó asafoetida      0.61   gramas
#
#                               image  Quantidade
# 0     chinese-five-spice-powder.png         210
# 1                  acorn-squash.jpg          13
# 2                       harissa.jpg         160
# 3                         agave.png         270
# 4                    tuna-steak.png          27
# 5                 alfredo-sauce.png         120
# 6                       extract.png         270
# 7   almond-meal-or-almond-flour.jpg         150
# 8                   almond-milk.png         170
# 9                       almonds.jpg          25
# 10     temporary-orange-liqueur.jpg         270
# 11           dried-arbol-chiles.jpg         130
# 12                    anchovies.jpg          19
# 13               smoked-sausage.jpg          20
# 14              angel-food-cake.jpg          16
# 15                    angelhair.jpg          10
# 16                   dark-sauce.jpg         140
# 17                        apple.jpg          28
# 18                  apple-jelly.jpg         250
# 19                  apple-cider.jpg         140
# 20                  apple-juice.jpg         230
# 21                 garam-masala.jpg         240
# 22                  apricot-jam.jpg         230
# 23                      apricot.jpg         300
# 24                 arborio-rice.png         190
# 25                 white-powder.jpg         270
# 26             artichoke-hearts.png          16
# 27                   artichokes.png          13
# 28      arugula-or-rocket-salad.jpg          22
# 29                 curry-powder.jpg         260

# %%
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=LUCCA-NOTEBOOK;'
                      'Database=siteMercado;'
                      'Trusted_Connection=yes;')

cursor = conn.cursor()
# Out:
# "conn = pyodbc.connect('Driver={SQL Server};'\n                      'Server=LUCCA-NOTEBOOK;'\n                      'Database=Mercado;'\n                      'Trusted_Connection=yes;')\n\ncursor = conn.cursor()"

# %%
TableColumns = "Nome, Valor, Unidade, Quantidade, Imagem"
for index, linha in df.iterrows():
    values_tuple = (
        linha['Nome'], linha['Valor R$'], linha['Quantidade'], linha['Unidade'], linha['image']
    )
    cursor.execute(f"INSERT INTO MusicFeaturesTB2 ({TableColumns}) VALUES (?, ?, ?, ?, ?)", values_tuple)

cursor.commit()
# Out:
# 'TableColumns = "Nome, Valor, Unidade, Quantidade, Imagem"\nfor index, linha in df.iterrows():\n    values_tuple = (\n        linha[\'Nome\'], linha[\'Valor R$\'], linha[\'Quantidade\'], linha[\'Unidade\'], linha[\'image\']\n    )\n    cursor.execute(f"INSERT INTO MusicFeaturesTB2 ({TableColumns}) VALUES (?, ?, ?, ?, ?)", values_tuple)\n\ncursor.commit()\n'
